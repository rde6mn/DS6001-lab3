# %% [markdown]
# # Lab Assignment 4: How to Use APIs in Python
# ## DS 6001

# %% [markdown]
# ### Instructions
# Please answer the following questions as completely as possible using text, code, and the results of code as needed. Format your answers in a Jupyter notebook. To receive full credit, make sure you address every part of the problem, and make sure your document is formatted in a clean and professional way.
#
# ## Problem 0
# Import the following packages:

# %%
import numpy as np
import pandas as pd
import requests
import json
import os
import dotenv
import lyricsgenius

r = requests.get('https://httpbin.org/user-agent')

# %%
useragent = json.loads(r.text)['user-agent'] #This saves your user-agent string for use later

# %% [markdown]
# ## Problem 1
# The hardest part of working with an API is finding and understanding the API's documentation. While the documentation (if it exists!) is essential for helping you to navigate to the data you need, they are also dense and technical.
#
# One big reason why API documentation is difficult is that it has to speak to all use-cases. Very often, when software engineers interact with an API like genius.com's, they are building apps. Imagine that you are hired to build an events and ticketing app for a local music venue. You might want to embed a list of albums, songs, and background information in your app by connecting to the Genius API (for song lyrics and artist information) and pulling that data into your app. You might run a record label and you want to interact with this API by posting information about the musicians you've signed. Or you might want to collect data on the users of genius.com for marketing research. The documentation must provide enough information to support all of these uses. As a result, documentation tends to be very long, and most of the information you will see is neither relevant nor easy to understand. That is okay, and should be the expectation.
#
# To effectively use API documentation, take a deep breath. Then narrow your search through the documentation to only these four things:
#
# 1. **The root**: We make requests from an API by, in part, writing out a complicated URL. In Python, we will compile the segments of this URL and let the `requests` package build the right URL. The first segment is the root, or the shared beginning of every URL associated with this API. Roots sometimes also include a version number such as /v2 or /v3. Your first task is to find the root and save it as a string in Python. One complaint I have about API documentation is that sometimes the root is a bit difficult to find, whereas I think it should be written in bold letters on the homepage. Sometimes I have to look for *example calls* to the API to see the root being used.
#
# 2. **The endpoints**: The next part of an API call's URL (generally after the first slash / but before the question mark) is called the endpoint. Very commonly, APIs have many endpoints for many different types of data. Genius for example has separate endpoints for songs, artists, user accounts, its search engine, and other types of functions. Sometimes endpoints are called "resources" or something similar, but you can generally tell an endpoint because it is denoted with a slash first, such as Genius's /songs, /artists, /accounts, and /search sections under resources. Your task here is to find the endpoint or endpoints that can give you the data you need by reading their descriptions in the documentation.
#
# 3. **The endpoint parameters**: Some endpoints will also have a list of parameters that control the selection of data a request will return. There are two ways that these parameters can appear in an API call's URL. First, they can appear as "query parameters" after a question mark, using equal signs to specify parameter values, and separating parameters with & signs. If you write these parameters in a dictionary and use the `params` argument in the `requests.get()` method to supply these parameters to the API, then `requests` will format the URL properly for you. The other way parameters might appear is as "path parameters" which are part of the endpoint, sometimes surrounded by {curly braces}: this format implies that the parameter value should be part of the endpoint you supply to `requests.get()` instead of an entry in the `params` argument. Either way, your task here is to find the parameters that enable you to get the data you need and to use the correct names and values of these parameters in your Python code.
#
# 4. **How to acquire API authentication or access keys, and how to supply these credentials when interacting with the API**: It's important to remember that APIs are designed to give the data owners control over how their data is shared with users like you. There is a political dimension to that: a data owner can choose what to divulge or keep private. There's also a financial dimension: websites can charge you at varying rates for using the API, can restrict the speed and volume of your requests to prevent you from overloading systems or profiting too much off of their work, or can use a "freemium" model where only a small amount of data is free but more data carries charges. Many APIs require you to register in advance and acquire secret codes (called keys or tokens) that must be supplied back to the API to enable your use. You have two tasks here. First you need to find instructions in the documentation for acquiring API access keys, paying particular attention to whether they are asking for a credit card (Genius does not) and if so what they might charge you, and what limits exist on the amount of data you can grab. Second, you need to find the instructions for supplying your key to the API. Sometimes that will be one of the endpoint parameters, and sometimes it will be in the headers along with your user-agent string. (When providing an API key via the headers, there's a common format that requires you to write the word "Bearer" and a space before your key. You are likely to see this format pop up sometimes.)
#
# For the following problems, describe in words how you can get the data in question. Use the API documentation linked in each question. Be specific about
#
# * the root,
# * endpoint,
# * parameters,
# * method of acquiring keys,
# * method for supplying these keys during an API call,
# * and whether and how using the API costs money, or is limited to only certain quantities of data.
#
# If there is more than one way to accomplish a task, describing just one of the valid approaches is fine.
#
# Do not write Python code to accomplish these steps. Focus on reading the documentation and understanding what you would need to do if you did attempt to get the data. Also, do NOT give any of these websites a credit card or other payment information, and please do not copy and paste your API keys into this document.

# %% [markdown]
# ### Part a
# How would you get data on the top 50 headlines from Germany today on the topic of sports? Use the News API, with documentation here: https://newsapi.org/docs (Hint: here's a list of country codes: https://en.wikipedia.org/wiki/ISO_3166-1_alpha-2) [12 points]

# %% [markdown]
# I got the data for the root by looking at the endpoint documentaiton. In their example code, they display the correct format. From documentation > endpoint > everything, we already know that it has 2 poisssible endpoints: /v2/everything and /v2/top-headlines, and by removing that from the example, we get https://newsapi.org for the root. For this example, we would use the /v2/top-headlines endpoint, since we want to look at the headlines. The avaliable paramters for use can also be found form documentation > endpoint > top headlines. When querying the api, we would need to use the following fields in params: apiKey (required and can be obtained frmo the website), country (set equal to DE for Germany), category (set equal to sports), and pageSize (set equal to 50 to get the most recent 50 results). This API usage is free for limited quantities of data, and past those quantities, the API costs money.

# %% [markdown]
# ### Part b
# How would you get JSON formatted data on the 100 most recent house resolutions (bills that passed a vote in the House of Representatives) in the 119th congress (elected in 2024) from the API of the U.S Congress? The documentation for this API is here: https://api.congress.gov/ [12 points]

# %% [markdown]
# First you would need to sign up for an API key by providing some information on the website. This api key will be fed into params later into the arg apiKey.
#
# The root and the endpoint can be founbd from any of the GET dropdowns. In the example request the beginning part of the request gives the root: https://api.congress.gov/v3. The endpoint is on the main part of the dropdown (the part that stays the same regardless of whethr you click on it). Based on the informatoin needed, the endopint would be:
# /bill/{congress}/{billType}. The available parameters for use are given inside the dropdown, so for this case we wluld need to set values for the follwing fields in params: congress (set equal to 119 to get the correct congress), billType (set equal to hres for house resolutions), format (set equal to json to get json values), limit (set equal to 100 to get the correct amount), sort (set equal to updateDate+desc to get most recent ones), and lastly, set apiKey to the key obtained from the website. This API is free for use.

# %% [markdown]
# ### Part c
# How would you get a real-time property value estimate for a specific address, say [1 Lewis Mountain Parkway, Charlottesville, VA 22904](https://wineandcountrylife.com/featured_item/lewis-mountain/) for example, using the RentCast API? The API documentation is here: https://developers.rentcast.io/reference/introduction When calculating costs, suppose I want to repeat this for each of 25,000 Charlottesville area addresses. [12 points]

# %% [markdown]
# First you would need to create a RentCast account and provide payment to get access to an API key (this API costs money just to use and is not free). From Getting Started > Authenticating API requests, I can find the root in the example code, which is https://api.rentcast.io/v1/. There are a few different enpoints, and these endpoints can be found  by clicking on the relevant sections from the left hand ( like Property Data, Rental Listings, etc) and then getting the section of the request url next to the GET and after the root value. For this current example, we are interested in Calue Estimate, and after going to that page and scrolling down, we can see that the corresponding enpoint is /avm/value for a building's value. In params you would set apiKey equal to the key obtained frmo the beginnign frmo the website, and you would set the address value to the address being used. From the JSON output, you would get the specific price frmo ['price'].
#
# If you wanted to do this for 25,000 addresses, you would need to pay 449 per month at the Scale level

# %% [markdown]
# ## Problem 2
#
# Next we'll work through the steps to access the Genius API and bring data from this API into Python.
#
# ### Part a
# Genius.com's API is documented here: https://docs.genius.com/#/getting-started-h1.
#
# Follow the same process you used in problem 1 to find the information you need to use this API. Start with learning about how to use the search endpoint to do a search for "Bob Dylan". Write briefly your findings regarding the root, endpoint, parameters, method of acquiring keys, and the method for supplying these keys during an API call. In this case, you are specifically looking for a credential called an Access Token. This API is free and has minimal restrictions, so no need to look for that information this time.
#
# (Hint: because you are just trying to pull data, and not set up access for additional registered users, look for "Access for Apps Without Users" in the Authentication section of the API documentation. You can find the "API Client management page" by clicking "Manage Clients" on the left.) [12 points]

# %% [markdown]
# Going to the Artists section, we can see that search is the endpoint for this problem, as that is located next to the GET. the example code provides api.genius.com/ as the root.  There is only one parameter : q. In params, q would be be set equal to "'Bob Dylan'" to find all information on that singer.

# %% [markdown]
# ### Part b
# Create a `.env` file for this project. The easiest way to do this in VS Code is to click on File -> New File, then name the file ".env" exactly, with no additional characters.
#
# Open the .env file, copy your Genius access token into it with a name, and save it. Then use Python code to load this environmental variable and save it as a Python variable. (You can print the access token to make sure it worked, but do not allow your access token to display in your final notebook). [12 points]

# %%
dotenv.load_dotenv()
# Out:
# True

# %%
geniuskey = os.getenv("geniuskey")

# %% [markdown]
# ### Part c
# Using the `requests` package in Python, connect to the Genius API's /search endpoint and search for "Bob Dylan". Remember to include a dictionary under `headers` that includes your user-agent string.
#
# The output will be in JSON format. Genius's API is organized in a way that every individual artist has his or her own API endpoint with more detailed information about the artist. Display the portion of the JSON output that displays the API endpoint path for the data on Bob Dylan. (Hint: it is listed under `primary_artist` several branches down the JSON tree.) [14 points]

# %%
root = "https://api.genius.com/"
endpoint = "search"
url = root + endpoint

# %%
headers = {'User-Agent': useragent,
           'From': 'rde6mn@virginia.edu'}

# %%
params = {'q': 'Bob Dylan',
          'access_token': geniuskey}

# %%
r = requests.get(url, headers=headers, params=params)

# %%
r.json() #see json output to find record path
# Out:
# {'meta': {'status': 200},
#  'response': {'hits': [{'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 12,
#      'api_path': '/songs/79424',
#      'artist_names': 'Bob Dylan',
#      'full_title': "Blowin' in the Wind by\xa0Bob\xa0Dylan",
#      'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'id': 79424,
#      'lyrics_owner_id': 73267,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-blowin-in-the-wind-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 49,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-blowin-in-the-wind-sample',
#      'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#      'release_date_for_display': 'May 27, 1963',
#      'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 705361},
#      'title': 'Blowin’ in the Wind',
#      'title_with_featured': "Blowin' in the Wind",
#      'url': 'https://genius.com/Bob-dylan-blowin-in-the-wind-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 19,
#      'api_path': '/songs/62605',
#      'artist_names': 'Bob Dylan',
#      'full_title': "The Times They Are A-Changin' by\xa0Bob\xa0Dylan",
#      'header_image_thumbnail_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.571x571x1.jpg',
#      'id': 62605,
#      'lyrics_owner_id': 49202,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-the-times-they-are-a-changin-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 44,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-the-times-they-are-a-changin-sample',
#      'release_date_components': {'year': 1964, 'month': 1, 'day': 13},
#      'release_date_for_display': 'January 13, 1964',
#      'release_date_with_abbreviated_month_for_display': 'Jan. 13, 1964',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.571x571x1.jpg',
#      'stats': {'unreviewed_annotations': 4,
#       'concurrents': 2,
#       'hot': False,
#       'pageviews': 600296},
#      'title': 'The Times They Are A-Changin’',
#      'title_with_featured': "The Times They Are A-Changin'",
#      'url': 'https://genius.com/Bob-dylan-the-times-they-are-a-changin-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 31,
#      'api_path': '/songs/54784',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Like a Rolling Stone by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.550x550x1.jpg',
#      'id': 54784,
#      'lyrics_owner_id': 7,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-like-a-rolling-stone-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 66,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-like-a-rolling-stone-sample',
#      'release_date_components': {'year': 1965, 'month': 7, 'day': 20},
#      'release_date_for_display': 'July 20, 1965',
#      'release_date_with_abbreviated_month_for_display': 'Jul. 20, 1965',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.550x550x1.jpg',
#      'stats': {'unreviewed_annotations': 15,
#       'concurrents': 2,
#       'hot': False,
#       'pageviews': 585539},
#      'title': 'Like a Rolling Stone',
#      'title_with_featured': 'Like a Rolling Stone',
#      'url': 'https://genius.com/Bob-dylan-like-a-rolling-stone-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 15,
#      'api_path': '/songs/98664',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'All Along the Watchtower by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.320x320x1.jpg',
#      'id': 98664,
#      'lyrics_owner_id': 779,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-all-along-the-watchtower-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 44,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-all-along-the-watchtower-sample',
#      'release_date_components': {'year': 1967, 'month': 12, 'day': 27},
#      'release_date_for_display': 'December 27, 1967',
#      'release_date_with_abbreviated_month_for_display': 'Dec. 27, 1967',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.320x320x1.jpg',
#      'stats': {'unreviewed_annotations': 0,
#       'concurrents': 3,
#       'hot': False,
#       'pageviews': 549707},
#      'title': 'All Along the Watchtower',
#      'title_with_featured': 'All Along the Watchtower',
#      'url': 'https://genius.com/Bob-dylan-all-along-the-watchtower-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 128,
#      'api_path': '/songs/5393247',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Murder Most Foul by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.1000x1000x1.jpg',
#      'id': 5393247,
#      'lyrics_owner_id': 3360167,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-murder-most-foul-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 37,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-murder-most-foul-sample',
#      'release_date_components': {'year': 2020, 'month': 3, 'day': 27},
#      'release_date_for_display': 'March 27, 2020',
#      'release_date_with_abbreviated_month_for_display': 'Mar. 27, 2020',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 40,
#       'hot': False,
#       'pageviews': 519528},
#      'title': 'Murder Most Foul',
#      'title_with_featured': 'Murder Most Foul',
#      'url': 'https://genius.com/Bob-dylan-murder-most-foul-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 10,
#      'api_path': '/songs/84846',
#      'artist_names': 'Bob Dylan',
#      'full_title': "Don't Think Twice, It's All Right by\xa0Bob\xa0Dylan",
#      'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'id': 84846,
#      'lyrics_owner_id': 125524,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-dont-think-twice-its-all-right-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 31,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-dont-think-twice-its-all-right-sample',
#      'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#      'release_date_for_display': 'May 27, 1963',
#      'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 487420},
#      'title': 'Don’t Think Twice, It’s All Right',
#      'title_with_featured': "Don't Think Twice, It's All Right",
#      'url': 'https://genius.com/Bob-dylan-dont-think-twice-its-all-right-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 32,
#      'api_path': '/songs/87402',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Hurricane by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.300x299x1.jpg',
#      'header_image_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.567x566x1.jpg',
#      'id': 87402,
#      'lyrics_owner_id': 132320,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-hurricane-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 27,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-hurricane-sample',
#      'release_date_components': {'year': 1976, 'month': 1, 'day': 5},
#      'release_date_for_display': 'January 5, 1976',
#      'release_date_with_abbreviated_month_for_display': 'Jan. 5, 1976',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.300x299x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.567x566x1.jpg',
#      'stats': {'unreviewed_annotations': 7, 'hot': False, 'pageviews': 441058},
#      'title': 'Hurricane',
#      'title_with_featured': 'Hurricane',
#      'url': 'https://genius.com/Bob-dylan-hurricane-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 21,
#      'api_path': '/songs/224',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Subterranean Homesick Blues by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.1000x1000x1.jpg',
#      'id': 224,
#      'lyrics_owner_id': 4,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-subterranean-homesick-blues-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 37,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-subterranean-homesick-blues-sample',
#      'release_date_components': {'year': 1965, 'month': 3, 'day': 8},
#      'release_date_for_display': 'March 8, 1965',
#      'release_date_with_abbreviated_month_for_display': 'Mar. 8, 1965',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 404294},
#      'title': 'Subterranean Homesick Blues',
#      'title_with_featured': 'Subterranean Homesick Blues',
#      'url': 'https://genius.com/Bob-dylan-subterranean-homesick-blues-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 10,
#      'api_path': '/songs/79749',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Make You Feel My Love by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.1000x1000x1.jpg',
#      'id': 79749,
#      'lyrics_owner_id': 5307,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-make-you-feel-my-love-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 10,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-make-you-feel-my-love-sample',
#      'release_date_components': {'year': 1997, 'month': 9, 'day': 30},
#      'release_date_for_display': 'September 30, 1997',
#      'release_date_with_abbreviated_month_for_display': 'Sep. 30, 1997',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 391480},
#      'title': 'Make You Feel My Love',
#      'title_with_featured': 'Make You Feel My Love',
#      'url': 'https://genius.com/Bob-dylan-make-you-feel-my-love-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 41,
#      'api_path': '/songs/105186',
#      'artist_names': 'Bob Dylan',
#      'full_title': "A Hard Rain's A-Gonna Fall by\xa0Bob\xa0Dylan",
#      'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'id': 105186,
#      'lyrics_owner_id': 16,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-a-hard-rains-a-gonna-fall-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 24,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-a-hard-rains-a-gonna-fall-sample',
#      'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#      'release_date_for_display': 'May 27, 1963',
#      'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 389829},
#      'title': 'A Hard Rain’s A-Gonna Fall',
#      'title_with_featured': "A Hard Rain's A-Gonna Fall",
#      'url': 'https://genius.com/Bob-dylan-a-hard-rains-a-gonna-fall-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}}]}}

# %%
r.json()['response']['hits'][0]['result']['primary_artist']
# Out:
# {'api_path': '/artists/181',
#  'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#  'id': 181,
#  'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#  'is_meme_verified': False,
#  'is_verified': False,
#  'name': 'Bob Dylan',
#  'url': 'https://genius.com/artists/Bob-dylan'}

# %% [markdown]
# /artists/181 is the artist path

# %% [markdown]
# ### Part d
# Add `/songs` to the end of the the endpoint path you found in problem 3 and use this path to request the 20 most popular songs written by Bob Dylan (some of these may be performed by other artists because Dylan is one of the most frequently covered musicians of all time). Organize these data in a `pandas` data frame. [14 points]

# %%
root = "https://api.genius.com/"
endpoint = "artists/181/songs"
url = root + endpoint

# %%
params = {'access_token': geniuskey,
          'per_page': 20}

# %%
r = requests.get(url, headers=headers, params=params)

# %%
r.json()
# Out:
# {'meta': {'status': 200},
#  'response': {'songs': [{'annotation_count': 0,
#     'api_path': '/songs/200681',
#     'artist_names': 'Bob Dylan',
#     'full_title': '10,000 Men by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/9a0da499b7383ddf232734cfb860d33b.300x301x1.jpg',
#     'header_image_url': 'https://images.genius.com/9a0da499b7383ddf232734cfb860d33b.500x501x1.jpg',
#     'id': 200681,
#     'lyrics_owner_id': 225680,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-10000-men-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-10000-men-sample',
#     'release_date_components': {'year': 1990, 'month': 9, 'day': 10},
#     'release_date_for_display': 'September 10, 1990',
#     'release_date_with_abbreviated_month_for_display': 'Sep. 10, 1990',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/9a0da499b7383ddf232734cfb860d33b.300x301x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/9a0da499b7383ddf232734cfb860d33b.500x501x1.jpg',
#     'stats': {'unreviewed_annotations': 0, 'hot': False},
#     'title': '10,000 Men',
#     'title_with_featured': '10,000 Men',
#     'url': 'https://genius.com/Bob-dylan-10000-men-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 0,
#     'api_path': '/songs/7105561',
#     'artist_names': 'Bob Dylan & The Band',
#     'full_title': '2 Dollars and 99 Cents by\xa0Bob\xa0Dylan & The\xa0Band',
#     'header_image_thumbnail_url': 'https://images.genius.com/84a940f13d290fc51835d36bca5b6d4f.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/84a940f13d290fc51835d36bca5b6d4f.1000x1000x1.jpg',
#     'id': 7105561,
#     'lyrics_owner_id': 6190893,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-and-the-band-2-dollars-and-99-cents-lyrics',
#     'primary_artist_names': 'Bob Dylan & The Band',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-and-the-band-2-dollars-and-99-cents-sample',
#     'release_date_components': {'year': 2014, 'month': 11, 'day': 4},
#     'release_date_for_display': 'November 4, 2014',
#     'release_date_with_abbreviated_month_for_display': 'Nov. 4, 2014',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/84a940f13d290fc51835d36bca5b6d4f.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/84a940f13d290fc51835d36bca5b6d4f.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 0, 'hot': False},
#     'title': '2 Dollars and 99 Cents',
#     'title_with_featured': '2 Dollars and 99 Cents',
#     'url': 'https://genius.com/Bob-dylan-and-the-band-2-dollars-and-99-cents-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      {'api_path': '/artists/4946',
#       'header_image_url': 'https://images.genius.com/f43f4f40448e40e880720dd1b6b6293c.1000x530x1.jpg',
#       'id': 4946,
#       'image_url': 'https://images.genius.com/98f9a6453309ee61717a067850923ceb.495x495x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'The Band',
#       'url': 'https://genius.com/artists/The-band'}]},
#    {'annotation_count': 1,
#     'api_path': '/songs/200682',
#     'artist_names': 'Bob Dylan',
#     'full_title': '2 X 2 by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/9a0da499b7383ddf232734cfb860d33b.300x301x1.jpg',
#     'header_image_url': 'https://images.genius.com/9a0da499b7383ddf232734cfb860d33b.500x501x1.jpg',
#     'id': 200682,
#     'lyrics_owner_id': 225680,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-2-x-2-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-2-x-2-sample',
#     'release_date_components': {'year': 1990, 'month': 9, 'day': 10},
#     'release_date_for_display': 'September 10, 1990',
#     'release_date_with_abbreviated_month_for_display': 'Sep. 10, 1990',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/9a0da499b7383ddf232734cfb860d33b.300x301x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/9a0da499b7383ddf232734cfb860d33b.500x501x1.jpg',
#     'stats': {'unreviewed_annotations': 0, 'hot': False},
#     'title': '2 X 2',
#     'title_with_featured': '2 X 2',
#     'url': 'https://genius.com/Bob-dylan-2-x-2-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 1,
#     'api_path': '/songs/1686914',
#     'artist_names': 'Bob Dylan',
#     'full_title': '32-20 Blues by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/dec36dae98920363912fa5db00a37d6e.300x300x1.png',
#     'header_image_url': 'https://images.genius.com/dec36dae98920363912fa5db00a37d6e.1000x1000x1.png',
#     'id': 1686914,
#     'lyrics_owner_id': 1549345,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-32-20-blues-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-32-20-blues-sample',
#     'release_date_components': {'year': 2008, 'month': 10, 'day': 6},
#     'release_date_for_display': 'October 6, 2008',
#     'release_date_with_abbreviated_month_for_display': 'Oct. 6, 2008',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/dec36dae98920363912fa5db00a37d6e.300x300x1.png',
#     'song_art_image_url': 'https://images.genius.com/dec36dae98920363912fa5db00a37d6e.1000x1000x1.png',
#     'stats': {'unreviewed_annotations': 1, 'hot': False},
#     'title': '32-20 Blues',
#     'title_with_featured': '32-20 Blues',
#     'url': 'https://genius.com/Bob-dylan-32-20-blues-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 1,
#     'api_path': '/songs/994912',
#     'artist_names': 'Robyn Hitchcock',
#     'full_title': '4th Time Around by\xa0Robyn\xa0Hitchcock',
#     'header_image_thumbnail_url': 'https://images.genius.com/4476c7b6ab3bd711b40f0688743ec694.300x299x1.jpg',
#     'header_image_url': 'https://images.genius.com/4476c7b6ab3bd711b40f0688743ec694.300x299x1.jpg',
#     'id': 994912,
#     'lyrics_owner_id': 6821092,
#     'lyrics_state': 'complete',
#     'path': '/Robyn-hitchcock-4th-time-around-lyrics',
#     'primary_artist_names': 'Robyn Hitchcock',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/Robyn-hitchcock-4th-time-around-sample',
#     'release_date_components': {'year': 2002, 'month': None, 'day': None},
#     'release_date_for_display': '2002',
#     'release_date_with_abbreviated_month_for_display': '2002',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/4476c7b6ab3bd711b40f0688743ec694.300x299x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/4476c7b6ab3bd711b40f0688743ec694.300x299x1.jpg',
#     'stats': {'unreviewed_annotations': 0, 'hot': False},
#     'title': '4th Time Around',
#     'title_with_featured': '4th Time Around',
#     'url': 'https://genius.com/Robyn-hitchcock-4th-time-around-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/90989',
#      'header_image_url': 'https://images.genius.com/75e0332313e5e1a4c0761b74da4bbbdc.999x999x1.jpg',
#      'id': 90989,
#      'image_url': 'https://images.genius.com/75e0332313e5e1a4c0761b74da4bbbdc.999x999x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Robyn Hitchcock',
#      'url': 'https://genius.com/artists/Robyn-hitchcock'},
#     'primary_artists': [{'api_path': '/artists/90989',
#       'header_image_url': 'https://images.genius.com/75e0332313e5e1a4c0761b74da4bbbdc.999x999x1.jpg',
#       'id': 90989,
#       'image_url': 'https://images.genius.com/75e0332313e5e1a4c0761b74da4bbbdc.999x999x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Robyn Hitchcock',
#       'url': 'https://genius.com/artists/Robyn-hitchcock'}]},
#    {'annotation_count': 15,
#     'api_path': '/songs/105774',
#     'artist_names': 'Bob Dylan',
#     'full_title': '4th Time Around by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/cc1723c9063d7eee6c3fd0626943c85f.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/cc1723c9063d7eee6c3fd0626943c85f.1000x1000x1.jpg',
#     'id': 105774,
#     'lyrics_owner_id': 16,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-4th-time-around-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 3,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-4th-time-around-sample',
#     'release_date_components': {'year': 1966, 'month': 5, 'day': 16},
#     'release_date_for_display': 'May 16, 1966',
#     'release_date_with_abbreviated_month_for_display': 'May 16, 1966',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/cc1723c9063d7eee6c3fd0626943c85f.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/cc1723c9063d7eee6c3fd0626943c85f.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 10, 'hot': False, 'pageviews': 53439},
#     'title': '4th Time Around',
#     'title_with_featured': '4th Time Around',
#     'url': 'https://genius.com/Bob-dylan-4th-time-around-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 1,
#     'api_path': '/songs/2231554',
#     'artist_names': 'Oren Lavie - אורן לביא',
#     'full_title': '4th Time Around by\xa0Oren\xa0Lavie - אורן לביא',
#     'header_image_thumbnail_url': 'https://images.genius.com/5467e90c6f628d46c2c95ec229f8f6b4.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/5467e90c6f628d46c2c95ec229f8f6b4.1000x1000x1.jpg',
#     'id': 2231554,
#     'lyrics_owner_id': 1549345,
#     'lyrics_state': 'complete',
#     'path': '/Oren-lavie-4th-time-around-lyrics',
#     'primary_artist_names': 'Oren Lavie - אורן לביא',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/Oren-lavie-4th-time-around-sample',
#     'release_date_components': None,
#     'release_date_for_display': None,
#     'release_date_with_abbreviated_month_for_display': None,
#     'song_art_image_thumbnail_url': 'https://images.genius.com/5467e90c6f628d46c2c95ec229f8f6b4.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/5467e90c6f628d46c2c95ec229f8f6b4.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 0, 'hot': False},
#     'title': '4th Time Around',
#     'title_with_featured': '4th Time Around',
#     'url': 'https://genius.com/Oren-lavie-4th-time-around-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/380192',
#      'header_image_url': 'https://images.genius.com/20733ed90cf03e00cdecbfa924d2e2d9.1000x1000x1.jpg',
#      'id': 380192,
#      'image_url': 'https://images.genius.com/20733ed90cf03e00cdecbfa924d2e2d9.1000x1000x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Oren Lavie - אורן לביא',
#      'url': 'https://genius.com/artists/Oren-lavie'},
#     'primary_artists': [{'api_path': '/artists/380192',
#       'header_image_url': 'https://images.genius.com/20733ed90cf03e00cdecbfa924d2e2d9.1000x1000x1.jpg',
#       'id': 380192,
#       'image_url': 'https://images.genius.com/20733ed90cf03e00cdecbfa924d2e2d9.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Oren Lavie - אורן לביא',
#       'url': 'https://genius.com/artists/Oren-lavie'}]},
#    {'annotation_count': 0,
#     'api_path': '/songs/11874140',
#     'artist_names': 'Terry Melcher',
#     'full_title': '4th Time Around by\xa0Terry\xa0Melcher',
#     'header_image_thumbnail_url': 'https://images.genius.com/7b769ac24d26736e08a9bae96527eead.300x300x1.png',
#     'header_image_url': 'https://images.genius.com/7b769ac24d26736e08a9bae96527eead.1000x1000x1.png',
#     'id': 11874140,
#     'lyrics_owner_id': 22829264,
#     'lyrics_state': 'complete',
#     'path': '/Terry-melcher-4th-time-around-lyrics',
#     'primary_artist_names': 'Terry Melcher',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/Terry-melcher-4th-time-around-sample',
#     'release_date_components': {'year': 1974, 'month': 1, 'day': 1},
#     'release_date_for_display': 'January 1, 1974',
#     'release_date_with_abbreviated_month_for_display': 'Jan. 1, 1974',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/7b769ac24d26736e08a9bae96527eead.300x300x1.png',
#     'song_art_image_url': 'https://images.genius.com/7b769ac24d26736e08a9bae96527eead.1000x1000x1.png',
#     'stats': {'unreviewed_annotations': 0, 'hot': False},
#     'title': '4th Time Around',
#     'title_with_featured': '4th Time Around',
#     'url': 'https://genius.com/Terry-melcher-4th-time-around-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/45704',
#      'header_image_url': 'https://images.genius.com/aedb656e3a3d6825f0538cac524ff898.418x418x1.jpg',
#      'id': 45704,
#      'image_url': 'https://images.genius.com/aedb656e3a3d6825f0538cac524ff898.418x418x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Terry Melcher',
#      'url': 'https://genius.com/artists/Terry-melcher'},
#     'primary_artists': [{'api_path': '/artists/45704',
#       'header_image_url': 'https://images.genius.com/aedb656e3a3d6825f0538cac524ff898.418x418x1.jpg',
#       'id': 45704,
#       'image_url': 'https://images.genius.com/aedb656e3a3d6825f0538cac524ff898.418x418x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Terry Melcher',
#       'url': 'https://genius.com/artists/Terry-melcher'}]},
#    {'annotation_count': 1,
#     'api_path': '/songs/1493543',
#     'artist_names': 'Traveling Wilburys',
#     'full_title': '7 Deadly Sins by\xa0Traveling\xa0Wilburys',
#     'header_image_thumbnail_url': 'https://images.genius.com/eda586eb0d4993017d1728d6913bf8a2.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/eda586eb0d4993017d1728d6913bf8a2.1000x1000x1.jpg',
#     'id': 1493543,
#     'lyrics_owner_id': 1549345,
#     'lyrics_state': 'complete',
#     'path': '/Traveling-wilburys-7-deadly-sins-lyrics',
#     'primary_artist_names': 'Traveling Wilburys',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/Traveling-wilburys-7-deadly-sins-sample',
#     'release_date_components': {'year': 1990, 'month': None, 'day': None},
#     'release_date_for_display': '1990',
#     'release_date_with_abbreviated_month_for_display': '1990',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/eda586eb0d4993017d1728d6913bf8a2.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/eda586eb0d4993017d1728d6913bf8a2.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 0, 'hot': False},
#     'title': '7 Deadly Sins',
#     'title_with_featured': '7 Deadly Sins',
#     'url': 'https://genius.com/Traveling-wilburys-7-deadly-sins-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/60612',
#      'header_image_url': 'https://images.genius.com/609e88d8b00dca0919f0c741ffa2de96.1000x600x1.jpg',
#      'id': 60612,
#      'image_url': 'https://images.genius.com/c859d02ba3a25da3b1f95bf5e23b1262.795x795x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Traveling Wilburys',
#      'url': 'https://genius.com/artists/Traveling-wilburys'},
#     'primary_artists': [{'api_path': '/artists/60612',
#       'header_image_url': 'https://images.genius.com/609e88d8b00dca0919f0c741ffa2de96.1000x600x1.jpg',
#       'id': 60612,
#       'image_url': 'https://images.genius.com/c859d02ba3a25da3b1f95bf5e23b1262.795x795x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Traveling Wilburys',
#       'url': 'https://genius.com/artists/Traveling-wilburys'}]},
#    {'annotation_count': 1,
#     'api_path': '/songs/1994655',
#     'artist_names': 'Bob Dylan',
#     'full_title': '900 Miles from My Home by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'id': 1994655,
#     'lyrics_owner_id': 30682,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-900-miles-from-my-home-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-900-miles-from-my-home-sample',
#     'release_date_components': None,
#     'release_date_for_display': None,
#     'release_date_with_abbreviated_month_for_display': None,
#     'song_art_image_thumbnail_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'stats': {'unreviewed_annotations': 0, 'hot': False},
#     'title': '900 Miles from My Home',
#     'title_with_featured': '900 Miles from My Home',
#     'url': 'https://genius.com/Bob-dylan-900-miles-from-my-home-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 0,
#     'api_path': '/songs/7103550',
#     'artist_names': 'Bob Dylan & The Band',
#     'full_title': '900 Miles from My Home by\xa0Bob\xa0Dylan & The\xa0Band',
#     'header_image_thumbnail_url': 'https://images.genius.com/84a940f13d290fc51835d36bca5b6d4f.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/84a940f13d290fc51835d36bca5b6d4f.1000x1000x1.jpg',
#     'id': 7103550,
#     'lyrics_owner_id': 6190893,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-and-the-band-900-miles-from-my-home-lyrics',
#     'primary_artist_names': 'Bob Dylan & The Band',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-and-the-band-900-miles-from-my-home-sample',
#     'release_date_components': {'year': 2014, 'month': 11, 'day': 4},
#     'release_date_for_display': 'November 4, 2014',
#     'release_date_with_abbreviated_month_for_display': 'Nov. 4, 2014',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/84a940f13d290fc51835d36bca5b6d4f.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/84a940f13d290fc51835d36bca5b6d4f.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 0, 'hot': False},
#     'title': '900 Miles from My Home',
#     'title_with_featured': '900 Miles from My Home',
#     'url': 'https://genius.com/Bob-dylan-and-the-band-900-miles-from-my-home-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      {'api_path': '/artists/4946',
#       'header_image_url': 'https://images.genius.com/f43f4f40448e40e880720dd1b6b6293c.1000x530x1.jpg',
#       'id': 4946,
#       'image_url': 'https://images.genius.com/98f9a6453309ee61717a067850923ceb.495x495x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'The Band',
#       'url': 'https://genius.com/artists/The-band'}]},
#    {'annotation_count': 0,
#     'api_path': '/songs/7105812',
#     'artist_names': 'Bob Dylan & The Band',
#     'full_title': '900 Miles From My Home / Confidential (Hidden Track) by\xa0Bob\xa0Dylan & The\xa0Band',
#     'header_image_thumbnail_url': 'https://images.genius.com/84a940f13d290fc51835d36bca5b6d4f.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/84a940f13d290fc51835d36bca5b6d4f.1000x1000x1.jpg',
#     'id': 7105812,
#     'lyrics_owner_id': 6190893,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-and-the-band-900-miles-from-my-home-confidential-hidden-track-lyrics',
#     'primary_artist_names': 'Bob Dylan & The Band',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-and-the-band-900-miles-from-my-home-confidential-hidden-track-sample',
#     'release_date_components': {'year': 2014, 'month': 11, 'day': 4},
#     'release_date_for_display': 'November 4, 2014',
#     'release_date_with_abbreviated_month_for_display': 'Nov. 4, 2014',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/84a940f13d290fc51835d36bca5b6d4f.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/84a940f13d290fc51835d36bca5b6d4f.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 0, 'hot': False},
#     'title': '900 Miles From My Home / Confidential (Hidden Track)',
#     'title_with_featured': '900 Miles From My Home / Confidential (Hidden Track)',
#     'url': 'https://genius.com/Bob-dylan-and-the-band-900-miles-from-my-home-confidential-hidden-track-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      {'api_path': '/artists/4946',
#       'header_image_url': 'https://images.genius.com/f43f4f40448e40e880720dd1b6b6293c.1000x530x1.jpg',
#       'id': 4946,
#       'image_url': 'https://images.genius.com/98f9a6453309ee61717a067850923ceb.495x495x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'The Band',
#       'url': 'https://genius.com/artists/The-band'}]},
#    {'annotation_count': 1,
#     'api_path': '/songs/3805476',
#     'artist_names': 'Bob Dylan',
#     'full_title': 'A by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/9a246711137e818f4825502d5e3e1244.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/9a246711137e818f4825502d5e3e1244.1000x1000x1.jpg',
#     'id': 3805476,
#     'lyrics_owner_id': 6614072,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-a-annotated',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-a-sample',
#     'release_date_components': {'year': 2018, 'month': 6, 'day': 22},
#     'release_date_for_display': 'June 22, 2018',
#     'release_date_with_abbreviated_month_for_display': 'Jun. 22, 2018',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/9a246711137e818f4825502d5e3e1244.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/9a246711137e818f4825502d5e3e1244.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 1, 'hot': False},
#     'title': 'A',
#     'title_with_featured': 'A',
#     'url': 'https://genius.com/Bob-dylan-a-annotated',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 0,
#     'api_path': '/songs/5754536',
#     'artist_names': 'Gillian Welch',
#     'full_title': 'Abandoned Love by\xa0Gillian\xa0Welch',
#     'header_image_thumbnail_url': 'https://images.genius.com/9c5f4e16c1a98d20850b69d3acd0954a.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/9c5f4e16c1a98d20850b69d3acd0954a.1000x1000x1.jpg',
#     'id': 5754536,
#     'lyrics_owner_id': 1168310,
#     'lyrics_state': 'complete',
#     'path': '/Gillian-welch-abandoned-love-lyrics',
#     'primary_artist_names': 'Gillian Welch',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/Gillian-welch-abandoned-love-sample',
#     'release_date_components': None,
#     'release_date_for_display': None,
#     'release_date_with_abbreviated_month_for_display': None,
#     'song_art_image_thumbnail_url': 'https://images.genius.com/9c5f4e16c1a98d20850b69d3acd0954a.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/9c5f4e16c1a98d20850b69d3acd0954a.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 0, 'hot': False},
#     'title': 'Abandoned Love',
#     'title_with_featured': 'Abandoned Love',
#     'url': 'https://genius.com/Gillian-welch-abandoned-love-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/43258',
#      'header_image_url': 'https://images.genius.com/d19d268fb8da9eed55d2caf248e88f33.528x194x1.png',
#      'id': 43258,
#      'image_url': 'https://images.genius.com/a5d1a2970eb99dacca7078ea17cb9a93.640x640x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Gillian Welch',
#      'url': 'https://genius.com/artists/Gillian-welch'},
#     'primary_artists': [{'api_path': '/artists/43258',
#       'header_image_url': 'https://images.genius.com/d19d268fb8da9eed55d2caf248e88f33.528x194x1.png',
#       'id': 43258,
#       'image_url': 'https://images.genius.com/a5d1a2970eb99dacca7078ea17cb9a93.640x640x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Gillian Welch',
#       'url': 'https://genius.com/artists/Gillian-welch'}]},
#    {'annotation_count': 1,
#     'api_path': '/songs/1390070',
#     'artist_names': '\u200bThe Everly Brothers',
#     'full_title': 'Abandoned Love by\xa0\u200bThe\xa0Everly Brothers',
#     'header_image_thumbnail_url': 'https://images.genius.com/921ec747d472e263e7fc2121cfeae7ad.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/921ec747d472e263e7fc2121cfeae7ad.1000x1000x1.jpg',
#     'id': 1390070,
#     'lyrics_owner_id': 1549345,
#     'lyrics_state': 'complete',
#     'path': '/The-everly-brothers-abandoned-love-lyrics',
#     'primary_artist_names': '\u200bThe Everly Brothers',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/The-everly-brothers-abandoned-love-sample',
#     'release_date_components': {'year': 1985, 'month': 11, 'day': None},
#     'release_date_for_display': 'November 1985',
#     'release_date_with_abbreviated_month_for_display': 'Nov. 1985',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/921ec747d472e263e7fc2121cfeae7ad.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/921ec747d472e263e7fc2121cfeae7ad.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 0, 'hot': False},
#     'title': 'Abandoned Love',
#     'title_with_featured': 'Abandoned Love',
#     'url': 'https://genius.com/The-everly-brothers-abandoned-love-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/44139',
#      'header_image_url': 'https://images.genius.com/f1bea76bd837ee54f1a00d36dfb05e23.1000x563x1.jpg',
#      'id': 44139,
#      'image_url': 'https://images.genius.com/64945eb6f723abe47bf2b088b177e0c1.1000x1000x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': '\u200bThe Everly Brothers',
#      'url': 'https://genius.com/artists/The-everly-brothers'},
#     'primary_artists': [{'api_path': '/artists/44139',
#       'header_image_url': 'https://images.genius.com/f1bea76bd837ee54f1a00d36dfb05e23.1000x563x1.jpg',
#       'id': 44139,
#       'image_url': 'https://images.genius.com/64945eb6f723abe47bf2b088b177e0c1.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': '\u200bThe Everly Brothers',
#       'url': 'https://genius.com/artists/The-everly-brothers'}]},
#    {'annotation_count': 4,
#     'api_path': '/songs/118651',
#     'artist_names': 'Bob Dylan',
#     'full_title': 'Abandoned Love by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/3473ef0e3a751805b4da76c5ebd83189.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/3473ef0e3a751805b4da76c5ebd83189.1000x1000x1.jpg',
#     'id': 118651,
#     'lyrics_owner_id': 188147,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-abandoned-love-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 4,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-abandoned-love-sample',
#     'release_date_components': {'year': 1985, 'month': 11, 'day': 7},
#     'release_date_for_display': 'November 7, 1985',
#     'release_date_with_abbreviated_month_for_display': 'Nov. 7, 1985',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/3473ef0e3a751805b4da76c5ebd83189.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/3473ef0e3a751805b4da76c5ebd83189.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 11464},
#     'title': 'Abandoned Love',
#     'title_with_featured': 'Abandoned Love',
#     'url': 'https://genius.com/Bob-dylan-abandoned-love-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 1,
#     'api_path': '/songs/2234570',
#     'artist_names': 'Paul Rodgers (Ft. Nils Lofgren)',
#     'full_title': 'Abandoned Love by\xa0Paul\xa0Rodgers (Ft.\xa0Nils\xa0Lofgren)',
#     'header_image_thumbnail_url': 'https://images.genius.com/5467e90c6f628d46c2c95ec229f8f6b4.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/5467e90c6f628d46c2c95ec229f8f6b4.1000x1000x1.jpg',
#     'id': 2234570,
#     'lyrics_owner_id': 1168310,
#     'lyrics_state': 'complete',
#     'path': '/Paul-rodgers-abandoned-love-lyrics',
#     'primary_artist_names': 'Paul Rodgers',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/Paul-rodgers-abandoned-love-sample',
#     'release_date_components': None,
#     'release_date_for_display': None,
#     'release_date_with_abbreviated_month_for_display': None,
#     'song_art_image_thumbnail_url': 'https://images.genius.com/5467e90c6f628d46c2c95ec229f8f6b4.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/5467e90c6f628d46c2c95ec229f8f6b4.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 0, 'hot': False},
#     'title': 'Abandoned Love',
#     'title_with_featured': 'Abandoned Love (Ft.\xa0Nils\xa0Lofgren)',
#     'url': 'https://genius.com/Paul-rodgers-abandoned-love-lyrics',
#     'featured_artists': [{'api_path': '/artists/353090',
#       'header_image_url': 'https://images.genius.com/c2aad2d1c01335a5d63b2b981a6037dd.1000x327x1.jpg',
#       'id': 353090,
#       'image_url': 'https://images.genius.com/72ce7f3a0f0dc3d1a90cb9d39ba99d8d.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Nils Lofgren',
#       'url': 'https://genius.com/artists/Nils-lofgren'}],
#     'primary_artist': {'api_path': '/artists/356096',
#      'header_image_url': 'https://images.genius.com/edc688055ed39d4c4fb6f62ddf3e3931.304x304x1.jpg',
#      'id': 356096,
#      'image_url': 'https://images.genius.com/edc688055ed39d4c4fb6f62ddf3e3931.304x304x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Paul Rodgers',
#      'url': 'https://genius.com/artists/Paul-rodgers'},
#     'primary_artists': [{'api_path': '/artists/356096',
#       'header_image_url': 'https://images.genius.com/edc688055ed39d4c4fb6f62ddf3e3931.304x304x1.jpg',
#       'id': 356096,
#       'image_url': 'https://images.genius.com/edc688055ed39d4c4fb6f62ddf3e3931.304x304x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Paul Rodgers',
#       'url': 'https://genius.com/artists/Paul-rodgers'}]},
#    {'annotation_count': 1,
#     'api_path': '/songs/11844813',
#     'artist_names': 'Bob Dylan',
#     'full_title': 'Abandoned Love (Live at the Other End, 1975) by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'id': 11844813,
#     'lyrics_owner_id': 6074356,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-abandoned-love-live-at-the-other-end-1975-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-abandoned-love-live-at-the-other-end-1975-sample',
#     'release_date_components': None,
#     'release_date_for_display': None,
#     'release_date_with_abbreviated_month_for_display': None,
#     'song_art_image_thumbnail_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'stats': {'unreviewed_annotations': 1, 'hot': False},
#     'title': 'Abandoned Love (Live at the Other End, 1975)',
#     'title_with_featured': 'Abandoned Love (Live at the Other End, 1975)',
#     'url': 'https://genius.com/Bob-dylan-abandoned-love-live-at-the-other-end-1975-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 1,
#     'api_path': '/songs/7236491',
#     'artist_names': 'Bob Dylan',
#     'full_title': 'Abraham, Martin, and John (Rehearsal) by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/046f5a790beb6972f382fbf66b7fef38.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/046f5a790beb6972f382fbf66b7fef38.1000x1000x1.jpg',
#     'id': 7236491,
#     'lyrics_owner_id': 7486996,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-abraham-martin-and-john-rehearsal-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-abraham-martin-and-john-rehearsal-sample',
#     'release_date_components': None,
#     'release_date_for_display': None,
#     'release_date_with_abbreviated_month_for_display': None,
#     'song_art_image_thumbnail_url': 'https://images.genius.com/046f5a790beb6972f382fbf66b7fef38.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/046f5a790beb6972f382fbf66b7fef38.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 1, 'hot': False},
#     'title': 'Abraham, Martin, and John (Rehearsal)',
#     'title_with_featured': 'Abraham, Martin, and John (Rehearsal)',
#     'url': 'https://genius.com/Bob-dylan-abraham-martin-and-john-rehearsal-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 1,
#     'api_path': '/songs/941697',
#     'artist_names': 'George Harrison',
#     'full_title': 'Absolutely Sweet Marie by\xa0George\xa0Harrison',
#     'header_image_thumbnail_url': 'https://images.genius.com/a107d4ceec3046900f549453f8d0a271.300x284x1.jpg',
#     'header_image_url': 'https://images.genius.com/a107d4ceec3046900f549453f8d0a271.500x474x1.jpg',
#     'id': 941697,
#     'lyrics_owner_id': 1549345,
#     'lyrics_state': 'complete',
#     'path': '/George-harrison-absolutely-sweet-marie-lyrics',
#     'primary_artist_names': 'George Harrison',
#     'pyongs_count': None,
#     'relationships_index_url': 'https://genius.com/George-harrison-absolutely-sweet-marie-sample',
#     'release_date_components': {'year': 1993, 'month': 8, 'day': 24},
#     'release_date_for_display': 'August 24, 1993',
#     'release_date_with_abbreviated_month_for_display': 'Aug. 24, 1993',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/a107d4ceec3046900f549453f8d0a271.300x284x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/a107d4ceec3046900f549453f8d0a271.500x474x1.jpg',
#     'stats': {'unreviewed_annotations': 1, 'hot': False},
#     'title': 'Absolutely Sweet Marie',
#     'title_with_featured': 'Absolutely Sweet Marie',
#     'url': 'https://genius.com/George-harrison-absolutely-sweet-marie-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/33327',
#      'header_image_url': 'https://images.genius.com/841ce907d244286a25a8473428b70a29.268x240x102.gif',
#      'id': 33327,
#      'image_url': 'https://images.genius.com/5d7d13d8d01a345e19a915e22921d3ef.1000x1000x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'George Harrison',
#      'url': 'https://genius.com/artists/George-harrison'},
#     'primary_artists': [{'api_path': '/artists/33327',
#       'header_image_url': 'https://images.genius.com/841ce907d244286a25a8473428b70a29.268x240x102.gif',
#       'id': 33327,
#       'image_url': 'https://images.genius.com/5d7d13d8d01a345e19a915e22921d3ef.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'George Harrison',
#       'url': 'https://genius.com/artists/George-harrison'}]}],
#   'next_page': 2}}

# %%
top20songs = pd.json_normalize(r.json(), record_path=['response', 'songs'])

# %%
top20songs
# Out:
#     annotation_count         api_path                     artist_names  \
# 0                  0    /songs/200681                        Bob Dylan
# 1                  0   /songs/7105561             Bob Dylan & The Band
# 2                  1    /songs/200682                        Bob Dylan
# 3                  1   /songs/1686914                        Bob Dylan
# 4                  1    /songs/994912                  Robyn Hitchcock
# 5                 15    /songs/105774                        Bob Dylan
# 6                  1   /songs/2231554           Oren Lavie - אורן לביא
# 7                  0  /songs/11874140                    Terry Melcher
# 8                  1   /songs/1493543               Traveling Wilburys
# 9                  1   /songs/1994655                        Bob Dylan
# 10                 0   /songs/7103550             Bob Dylan & The Band
# 11                 0   /songs/7105812             Bob Dylan & The Band
# 12                 1   /songs/3805476                        Bob Dylan
# 13                 0   /songs/5754536                    Gillian Welch
# 14                 1   /songs/1390070             ​The Everly Brothers
# 15                 4    /songs/118651                        Bob Dylan
# 16                 1   /songs/2234570  Paul Rodgers (Ft. Nils Lofgren)
# 17                 1  /songs/11844813                        Bob Dylan
# 18                 1   /songs/7236491                        Bob Dylan
# 19                 1    /songs/941697                  George Harrison
#
#                                            full_title  \
# 0                             10,000 Men by Bob Dylan
# 1      2 Dollars and 99 Cents by Bob Dylan & The Band
# 2                                  2 X 2 by Bob Dylan
# 3                            32-20 Blues by Bob Dylan
# 4                  4th Time Around by Robyn Hitchcock
# 5                        4th Time Around by Bob Dylan
# 6           4th Time Around by Oren Lavie - אורן לביא
# 7                    4th Time Around by Terry Melcher
# 8                 7 Deadly Sins by Traveling Wilburys
# 9                 900 Miles from My Home by Bob Dylan
# 10     900 Miles from My Home by Bob Dylan & The Band
# 11  900 Miles From My Home / Confidential (Hidden ...
# 12                                     A by Bob Dylan
# 13                    Abandoned Love by Gillian Welch
# 14             Abandoned Love by ​The Everly Brothers
# 15                        Abandoned Love by Bob Dylan
# 16  Abandoned Love by Paul Rodgers (Ft. Nils Lofgren)
# 17  Abandoned Love (Live at the Other End, 1975) b...
# 18  Abraham, Martin, and John (Rehearsal) by Bob D...
# 19          Absolutely Sweet Marie by George Harrison
#
#                            header_image_thumbnail_url  \
# 0   https://images.genius.com/9a0da499b7383ddf2327...
# 1   https://images.genius.com/84a940f13d290fc51835...
# 2   https://images.genius.com/9a0da499b7383ddf2327...
# 3   https://images.genius.com/dec36dae98920363912f...
# 4   https://images.genius.com/4476c7b6ab3bd711b40f...
# 5   https://images.genius.com/cc1723c9063d7eee6c3f...
# 6   https://images.genius.com/5467e90c6f628d46c2c9...
# 7   https://images.genius.com/7b769ac24d26736e08a9...
# 8   https://images.genius.com/eda586eb0d4993017d17...
# 9   https://images.genius.com/f3c6518f8979ef5e0ee4...
# 10  https://images.genius.com/84a940f13d290fc51835...
# 11  https://images.genius.com/84a940f13d290fc51835...
# 12  https://images.genius.com/9a246711137e818f4825...
# 13  https://images.genius.com/9c5f4e16c1a98d20850b...
# 14  https://images.genius.com/921ec747d472e263e7fc...
# 15  https://images.genius.com/3473ef0e3a751805b4da...
# 16  https://images.genius.com/5467e90c6f628d46c2c9...
# 17  https://images.genius.com/f3c6518f8979ef5e0ee4...
# 18  https://images.genius.com/046f5a790beb6972f382...
# 19  https://images.genius.com/a107d4ceec3046900f54...
#
#                                      header_image_url        id  \
# 0   https://images.genius.com/9a0da499b7383ddf2327...    200681
# 1   https://images.genius.com/84a940f13d290fc51835...   7105561
# 2   https://images.genius.com/9a0da499b7383ddf2327...    200682
# 3   https://images.genius.com/dec36dae98920363912f...   1686914
# 4   https://images.genius.com/4476c7b6ab3bd711b40f...    994912
# 5   https://images.genius.com/cc1723c9063d7eee6c3f...    105774
# 6   https://images.genius.com/5467e90c6f628d46c2c9...   2231554
# 7   https://images.genius.com/7b769ac24d26736e08a9...  11874140
# 8   https://images.genius.com/eda586eb0d4993017d17...   1493543
# 9   https://images.genius.com/f3c6518f8979ef5e0ee4...   1994655
# 10  https://images.genius.com/84a940f13d290fc51835...   7103550
# 11  https://images.genius.com/84a940f13d290fc51835...   7105812
# 12  https://images.genius.com/9a246711137e818f4825...   3805476
# 13  https://images.genius.com/9c5f4e16c1a98d20850b...   5754536
# 14  https://images.genius.com/921ec747d472e263e7fc...   1390070
# 15  https://images.genius.com/3473ef0e3a751805b4da...    118651
# 16  https://images.genius.com/5467e90c6f628d46c2c9...   2234570
# 17  https://images.genius.com/f3c6518f8979ef5e0ee4...  11844813
# 18  https://images.genius.com/046f5a790beb6972f382...   7236491
# 19  https://images.genius.com/a107d4ceec3046900f54...    941697
#
#     lyrics_owner_id lyrics_state  \
# 0            225680     complete
# 1           6190893     complete
# 2            225680     complete
# 3           1549345     complete
# 4           6821092     complete
# 5                16     complete
# 6           1549345     complete
# 7          22829264     complete
# 8           1549345     complete
# 9             30682     complete
# 10          6190893     complete
# 11          6190893     complete
# 12          6614072     complete
# 13          1168310     complete
# 14          1549345     complete
# 15           188147     complete
# 16          1168310     complete
# 17          6074356     complete
# 18          7486996     complete
# 19          1549345     complete
#
#                                                  path  ...  \
# 0                         /Bob-dylan-10000-men-lyrics  ...
# 1   /Bob-dylan-and-the-band-2-dollars-and-99-cents...  ...
# 2                             /Bob-dylan-2-x-2-lyrics  ...
# 3                       /Bob-dylan-32-20-blues-lyrics  ...
# 4             /Robyn-hitchcock-4th-time-around-lyrics  ...
# 5                   /Bob-dylan-4th-time-around-lyrics  ...
# 6                  /Oren-lavie-4th-time-around-lyrics  ...
# 7               /Terry-melcher-4th-time-around-lyrics  ...
# 8            /Traveling-wilburys-7-deadly-sins-lyrics  ...
# 9            /Bob-dylan-900-miles-from-my-home-lyrics  ...
# 10  /Bob-dylan-and-the-band-900-miles-from-my-home...  ...
# 11  /Bob-dylan-and-the-band-900-miles-from-my-home...  ...
# 12                             /Bob-dylan-a-annotated  ...
# 13               /Gillian-welch-abandoned-love-lyrics  ...
# 14         /The-everly-brothers-abandoned-love-lyrics  ...
# 15                   /Bob-dylan-abandoned-love-lyrics  ...
# 16                /Paul-rodgers-abandoned-love-lyrics  ...
# 17  /Bob-dylan-abandoned-love-live-at-the-other-en...  ...
# 18  /Bob-dylan-abraham-martin-and-john-rehearsal-l...  ...
# 19     /George-harrison-absolutely-sweet-marie-lyrics  ...
#
#    primary_artist.api_path                    primary_artist.header_image_url  \
# 0             /artists/181  https://images.genius.com/f854c714833541117358...
# 1             /artists/181  https://images.genius.com/f854c714833541117358...
# 2             /artists/181  https://images.genius.com/f854c714833541117358...
# 3             /artists/181  https://images.genius.com/f854c714833541117358...
# 4           /artists/90989  https://images.genius.com/75e0332313e5e1a4c076...
# 5             /artists/181  https://images.genius.com/f854c714833541117358...
# 6          /artists/380192  https://images.genius.com/20733ed90cf03e00cdec...
# 7           /artists/45704  https://images.genius.com/aedb656e3a3d6825f053...
# 8           /artists/60612  https://images.genius.com/609e88d8b00dca0919f0...
# 9             /artists/181  https://images.genius.com/f854c714833541117358...
# 10            /artists/181  https://images.genius.com/f854c714833541117358...
# 11            /artists/181  https://images.genius.com/f854c714833541117358...
# 12            /artists/181  https://images.genius.com/f854c714833541117358...
# 13          /artists/43258  https://images.genius.com/d19d268fb8da9eed55d2...
# 14          /artists/44139  https://images.genius.com/f1bea76bd837ee54f1a0...
# 15            /artists/181  https://images.genius.com/f854c714833541117358...
# 16         /artists/356096  https://images.genius.com/edc688055ed39d4c4fb6...
# 17            /artists/181  https://images.genius.com/f854c714833541117358...
# 18            /artists/181  https://images.genius.com/f854c714833541117358...
# 19          /artists/33327  https://images.genius.com/841ce907d244286a25a8...
#
#    primary_artist.id                           primary_artist.image_url  \
# 0                181  https://images.genius.com/f3c6518f8979ef5e0ee4...
# 1                181  https://images.genius.com/f3c6518f8979ef5e0ee4...
# 2                181  https://images.genius.com/f3c6518f8979ef5e0ee4...
# 3                181  https://images.genius.com/f3c6518f8979ef5e0ee4...
# 4              90989  https://images.genius.com/75e0332313e5e1a4c076...
# 5                181  https://images.genius.com/f3c6518f8979ef5e0ee4...
# 6             380192  https://images.genius.com/20733ed90cf03e00cdec...
# 7              45704  https://images.genius.com/aedb656e3a3d6825f053...
# 8              60612  https://images.genius.com/c859d02ba3a25da3b1f9...
# 9                181  https://images.genius.com/f3c6518f8979ef5e0ee4...
# 10               181  https://images.genius.com/f3c6518f8979ef5e0ee4...
# 11               181  https://images.genius.com/f3c6518f8979ef5e0ee4...
# 12               181  https://images.genius.com/f3c6518f8979ef5e0ee4...
# 13             43258  https://images.genius.com/a5d1a2970eb99dacca70...
# 14             44139  https://images.genius.com/64945eb6f723abe47bf2...
# 15               181  https://images.genius.com/f3c6518f8979ef5e0ee4...
# 16            356096  https://images.genius.com/edc688055ed39d4c4fb6...
# 17               181  https://images.genius.com/f3c6518f8979ef5e0ee4...
# 18               181  https://images.genius.com/f3c6518f8979ef5e0ee4...
# 19             33327  https://images.genius.com/5d7d13d8d01a345e19a9...
#
#    primary_artist.is_meme_verified primary_artist.is_verified  \
# 0                            False                      False
# 1                            False                      False
# 2                            False                      False
# 3                            False                      False
# 4                            False                      False
# 5                            False                      False
# 6                            False                      False
# 7                            False                      False
# 8                            False                      False
# 9                            False                      False
# 10                           False                      False
# 11                           False                      False
# 12                           False                      False
# 13                           False                      False
# 14                           False                      False
# 15                           False                      False
# 16                           False                      False
# 17                           False                      False
# 18                           False                      False
# 19                           False                      False
#
#        primary_artist.name                              primary_artist.url  \
# 0                Bob Dylan            https://genius.com/artists/Bob-dylan
# 1                Bob Dylan            https://genius.com/artists/Bob-dylan
# 2                Bob Dylan            https://genius.com/artists/Bob-dylan
# 3                Bob Dylan            https://genius.com/artists/Bob-dylan
# 4          Robyn Hitchcock      https://genius.com/artists/Robyn-hitchcock
# 5                Bob Dylan            https://genius.com/artists/Bob-dylan
# 6   Oren Lavie - אורן לביא           https://genius.com/artists/Oren-lavie
# 7            Terry Melcher        https://genius.com/artists/Terry-melcher
# 8       Traveling Wilburys   https://genius.com/artists/Traveling-wilburys
# 9                Bob Dylan            https://genius.com/artists/Bob-dylan
# 10               Bob Dylan            https://genius.com/artists/Bob-dylan
# 11               Bob Dylan            https://genius.com/artists/Bob-dylan
# 12               Bob Dylan            https://genius.com/artists/Bob-dylan
# 13           Gillian Welch        https://genius.com/artists/Gillian-welch
# 14    ​The Everly Brothers  https://genius.com/artists/The-everly-brothers
# 15               Bob Dylan            https://genius.com/artists/Bob-dylan
# 16            Paul Rodgers         https://genius.com/artists/Paul-rodgers
# 17               Bob Dylan            https://genius.com/artists/Bob-dylan
# 18               Bob Dylan            https://genius.com/artists/Bob-dylan
# 19         George Harrison      https://genius.com/artists/George-harrison
#
#    stats.pageviews release_date_components
# 0              NaN                     NaN
# 1              NaN                     NaN
# 2              NaN                     NaN
# 3              NaN                     NaN
# 4              NaN                     NaN
# 5          53439.0                     NaN
# 6              NaN                     NaN
# 7              NaN                     NaN
# 8              NaN                     NaN
# 9              NaN                     NaN
# 10             NaN                     NaN
# 11             NaN                     NaN
# 12             NaN                     NaN
# 13             NaN                     NaN
# 14             NaN                     NaN
# 15         11464.0                     NaN
# 16             NaN                     NaN
# 17             NaN                     NaN
# 18             NaN                     NaN
# 19             NaN                     NaN
#
# [20 rows x 37 columns]

# %% [markdown]
# ## Problem 3
# One drawback of the Genius API is that is currently has no endpoint that returns song lyrics.
#
# The `lyricsgenius` package is a wrapper around `requests` and `BeautifulSoup`, the Python package for web-scraping data off of the raw HTML of a webpage. We will cover web-scraping in module 5. But for now, follow the guide on the GitHub repository for this package (https://github.com/johnwmillr/LyricsGenius) for instructions on using it. Then use `lyricsgenius` to download and display the lyrics to "Tangled Up in Blue" by Bob Dylan.
#
# Optional but recommended: call a loved one on the phone and sing "Tangled Up in Blue" to them. [12 points]

# %%
import lyricsgenius
genius = lyricsgenius.Genius(geniuskey)

# %%
artist = genius.search_artist("Bob Dylan", max_songs=3)
# Out:
# Searching for songs by Bob Dylan...
#
# Song 1: "Blowin’ in the Wind"
# Song 2: "The Times They Are A-Changin’"
# Song 3: "Like a Rolling Stone"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.

# %%
song = genius.search_song("Tangled Up In Blue", artist.name)

print(song.lyrics)
# Out:
# Searching for "Tangled Up In Blue" by Bob Dylan...
# Done.
# [Verse 1]
# Early one morning the sun was shining
# I was laying in bed
# Wondering if she'd changed at all
# If her hair was still red
# Her folks they said our lives together
# Sure was going to be rough
# They never did like Mama's homemade dress
# Papa's bankbook wasn't big enough
# And I was standing on the side of the road
# Rain falling on my shoes
# Heading out for the East Coast
# Lord knows I've paid some dues
# Getting through
# Tangled up in blue
#
# [Verse 2]
# She was married when we first met
# Soon to be divorced
# I helped her out of a jam, I guess
# But I used a little too much force
# We drove that car as far as we could
# Abandoned it out west
# Split up on a dark sad night
# Both agreeing it was best
# She turned around to look at me
# As I was walking away
# I heard her say over my shoulder
# "We'll meet again someday
# On the avenue"
# Tangled up in blue
#
# [Verse 3]
# I had a job in the great north woods
# Working as a cook for a spell
# But I never did like it all that much
# And one day the ax just fell
# So I drifted down to New Orleans
# Where I lucky was to be employed
# Working for a while on a fishing boat
# Right outside of Delacroix
# But all the while I was alone
# The past was close behind
# I seen a lot of women
# But she never escaped my mind
# And I just grew
# Tangled up in blue
#
# [Verse 4]
# She was working in a topless place
# And I stopped in for a beer
# I just kept looking at the side of her face
# In the spotlight, so clear
# And later on, when the crowd thinned out
# I was just about to do the same
# She was standing there, in back of my chair
# Said, "Tell me, don't I know your name?"
# I muttered something underneath my breath
# She studied the lines on my face
# I must admit, I felt a little uneasy
# When she bent down to tie the laces
# Of my shoe
# Tangled up in blue
#
# [Verse 5]
# She lit a burner on the stove
# And offered me a pipe
# "I thought you'd never say hello," she said
# "You look like the silent type"
# Then she opened up a book of poems
# And handed it to me
# Written by an Italian poet
# From the thirteenth century
# And every one of them words rang true
# And glowed like burning coal
# Pouring off of every page
# Like it was written in my soul
# From me to you
# Tangled up in blue
#
# [Verse 6]
# I lived with them on Montague Street
# In a basement down the stairs
# There was music in the cafes at night
# And revolution in the air
# Then he started into dealing with slaves
# And something inside of him died
# She had to sell everything she owned
# And froze up inside
# And when it finally, the bottom fell out
# I became withdrawn
# The only thing I knew how to do
# Was to keep on keeping on
# Like a bird that flew
# Tangled up in blue
#
# [Verse 7]
# So now I'm going back again
# I got to get to her somehow
# All the people we used to know
# They're an illusion to me now
# Some are mathematicians
# Some are carpenters' wives
# Don't know how it all got started
# I don't know what they're doing with their lives
# But me, I'm still on the road
# A-heading for another joint
# We always did feel the same
# We just saw it from a different point
# Of view
# Tangled up in blue
